# %%
x = 2 + 1
x
# Out:
# 3

# %%
"""
Hello, World!
"""
# 1. Print a string
print("This line will be printed.")

# 2. Indentation for blocks (four spaces)
x = 1
if x == 1: 
    # indented four spaces
    print("x is 1.")
# Out:
# This line will be printed.
# x is 1.

# %%
# """
# Test to see how display of a simple chart (here using matplotlib) works in VSCode does this ever end or what is my linter doing can somenbody tell me hello ehwdoasdofaosdjfaopsjdffoasjdgoijasdogjasdogij.
# """

import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(0, 20, 100)
y = np.sin(x)
plt.plot(x, y)
plt.show()
